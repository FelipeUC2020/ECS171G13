# %% [markdown]
# ### Recurrent Neural Network (LSTM)

# %% [markdown]
# This is a basic convolutional approach to sequence prediction using convolutions through TensorFlow!

# %% [markdown]
# We begin by important any relevant packages, modules, and the DataProcessor class (for our pre-processed data). Then we get our dataset ready.

# %%
from tensorflow.keras import backend as K
K.clear_session()

# %%
import os, sys
sys.path.append(os.path.abspath('..'))  # add parent directory to sys.path
from data_cleanup import DataProcessor
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.models import Sequential
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error
import numpy as np

# Define the windowing parameters
# Use 10 hours of history
INPUT_WINDOW = 10  
# Predict the next 1 hours
OUTPUT_WINDOW = 1 

# Initialize the class
processor = DataProcessor(input_steps=INPUT_WINDOW, output_steps=OUTPUT_WINDOW)

# Run the pipeline
(X_train, y_train), (X_val, y_val), (X_test, y_test) = processor.load_and_process_data()

# Check the final shapes
print("\n--- Final Data Shapes ---")
print(f"X_train shape: {X_train.shape}  | y_train shape: {y_train.shape}")
print(f"X_val shape:   {X_val.shape}     | y_val shape:   {y_val.shape}")
print(f"X_test shape:  {X_test.shape}    | y_test shape:  {y_test.shape}")
# Out:
# Step 1/5: Fetching, cleaning, and engineering features...
# /opt/anaconda3/envs/ds_env/lib/python3.11/site-packages/ucimlrepo/fetch.py:97: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_url)
# /Users/macychen/GithubProjects/ECS171G13/data_cleanup.py:135: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')
# /Users/macychen/GithubProjects/ECS171G13/data_cleanup.py:175: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   df_hourly = df.resample('H').agg(agg_dict)
# Step 2/5: Resampling data to hourly and setting 'Global_active_power' as target...
# Step 3/5: Splitting data and applying scaler...
# Step 4/5: Creating time-series windows...
# Step 5/5: Data processing complete.
#
# --- Final Data Shapes ---
# X_train shape: (25917, 10, 8)  | y_train shape: (25917, 1)
# X_val shape:   (3614, 10, 8)     | y_val shape:   (3614, 1)
# X_test shape:  (5028, 10, 8)    | y_test shape:  (5028, 1)
# /Users/macychen/GithubProjects/ECS171G13/data_cleanup.py:176: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_hourly = df_hourly.fillna(method='ffill')

# %% [markdown]
# Next, we want to build the model itself. Keras makes this very simple at a high-level, so tuning is also easy to do.

# %%
# Initialize the "order" of layers to be inserted. Will be a simple sequence.
model = Sequential()

# Add the first layer, which is an LSTM layer. We will choose to have 128 neurons, which sets the dimensionality seen
# throughout the LSTM layer.   
model.add(LSTM(units=128, input_shape=(10, 8)))

# The second layer is the final layer. This is a Dense one so we get one final hour to predict.
model.add(Dense(1))

# Set some parameters for how model will be optimized and how loss is calculated.
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# 2025-11-24 20:00:06.257821: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3
# 2025-11-24 20:00:06.258021: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2025-11-24 20:00:06.258041: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764043206.258362 31371712 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1764043206.258697 31371712 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# /opt/anaconda3/envs/ds_env/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# Now we want to fit the model, train it, and determine an error metric.

# %%
# This helper watches val_loss and stops training automatically if the model stops improving.
early_stopper = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

print("Starting model training...")
history = model.fit(
    X_train, 
    y_train, 
    epochs=10,                      
    batch_size=32,                  
    validation_data=(X_val, y_val), 
    callbacks=[early_stopper],      
    verbose=1
)
print("Training complete.")

print("Making predictions on the test set...")
# This gives you scaled predictions (e.g., 0.34, 0.52, etc.)
predictions_scaled = model.predict(X_test)

# Un-scale model's predictions
unscaled_predictions = processor.inverse_transform_predictions(predictions_scaled)

# Un-scale y_test so we can compare using the exact same helper function.
unscaled_y_test = processor.inverse_transform_predictions(y_test)


mse = mean_squared_error(unscaled_y_test, unscaled_predictions)
print(f'\n--- Model Evaluation ---')
print(f'Test Set MSE (Mean Squared Error): {mse:.4f}')

# This is the human-readable version 
rmse = np.sqrt(mse)
print(f'Test Set RMSE (Root Mean Squared Error): {rmse:.4f}')
print(f'(This means, on average, the model was off by approx. {rmse:.2f} kilowatts)')
# Out:
# Starting model training...
# Epoch 1/10
# 2025-11-24 20:00:22.259607: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 810/810 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0098 - val_loss: 0.0083
# Epoch 2/10
# 810/810 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0086 - val_loss: 0.0078
# Epoch 3/10
# 810/810 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0083 - val_loss: 0.0076
# Epoch 4/10
# 810/810 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0081 - val_loss: 0.0074
# Epoch 5/10
# 810/810 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0080 - val_loss: 0.0077
# Epoch 6/10
# 810/810 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0079 - val_loss: 0.0077
# Epoch 7/10
# 810/810 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0079 - val_loss: 0.0074
# Epoch 8/10
# 810/810 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0078 - val_loss: 0.0073
# Epoch 9/10
# 810/810 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0077 - val_loss: 0.0074
# Epoch 10/10
# 810/810 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0077 - val_loss: 0.0073
# Restoring model weights from the end of the best epoch: 8.
# Training complete.
# Making predictions on the test set...
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#
# --- Model Evaluation ---
# Test Set MSE (Mean Squared Error): 0.2426
# Test Set RMSE (Root Mean Squared Error): 0.4926
# (This means, on average, the model was off by approx. 0.49 kilowatts)

# %%
# Set number of folds
FOLDS = 3
tscv = TimeSeriesSplit(n_splits=FOLDS)

cv_mse = []
cv_rmse = []

fold = 1
for train_idx, val_idx in tscv.split(X_train):
    print(f"\n--- Fold {fold} ---")
    
    X_train_fold, X_val_fold = X_train[train_idx], X_train[val_idx]
    y_train_fold, y_val_fold = y_train[train_idx], y_train[val_idx]

    # Build LSTM model
    model = Sequential()
    model.add(LSTM(units=128, input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')

    # Early stopping
    early_stopper = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

    # Train
    history = model.fit(
        X_train_fold, y_train_fold,
        epochs=10,
        batch_size=32,
        validation_data=(X_val_fold, y_val_fold),
        callbacks=[early_stopper],
        verbose=1
    )

    # Predict on validation fold
    val_pred_scaled = model.predict(X_val_fold)
    val_pred_unscaled = processor.inverse_transform_predictions(val_pred_scaled)
    y_val_unscaled = processor.inverse_transform_predictions(y_val_fold)

    # Evaluate
    mse = mean_squared_error(y_val_unscaled, val_pred_unscaled)
    rmse = np.sqrt(mse)

    cv_mse.append(mse)
    cv_rmse.append(rmse)

    print(f"Fold {fold} MSE: {mse:.4f}, RMSE: {rmse:.4f}")
    fold += 1

# Average metrics across folds
print("\nCross-Validation Summary")
print(f"Average MSE: {np.mean(cv_mse):.4f}")
print(f"Average RMSE: {np.mean(cv_rmse):.4f}")
# Out:
# --- Fold 1 ---
# Epoch 1/10
# /opt/anaconda3/envs/ds_env/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0117 - val_loss: 0.0122
# Epoch 2/10
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0097 - val_loss: 0.0109
# Epoch 3/10
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0093 - val_loss: 0.0109
# Epoch 4/10
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0092 - val_loss: 0.0105
# Epoch 5/10
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0090 - val_loss: 0.0108
# Epoch 6/10
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0089 - val_loss: 0.0109
# Epoch 7/10
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0089 - val_loss: 0.0105
# Epoch 8/10
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0088 - val_loss: 0.0101
# Epoch 9/10
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0088 - val_loss: 0.0102
# Epoch 10/10
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0087 - val_loss: 0.0104
# Restoring model weights from the end of the best epoch: 8.
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Fold 1 MSE: 0.4165, RMSE: 0.6454
#
# --- Fold 2 ---
# Epoch 1/10
# /opt/anaconda3/envs/ds_env/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0119 - val_loss: 0.0086
# Epoch 2/10
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0100 - val_loss: 0.0083
# Epoch 3/10
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0096 - val_loss: 0.0080
# Epoch 4/10
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0095 - val_loss: 0.0081
# Epoch 5/10
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0095 - val_loss: 0.0080
# Epoch 6/10
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0093 - val_loss: 0.0078
# Epoch 7/10
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0093 - val_loss: 0.0076
# Epoch 8/10
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0092 - val_loss: 0.0076
# Epoch 9/10
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0091 - val_loss: 0.0076
# Epoch 10/10
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0090 - val_loss: 0.0076
# Restoring model weights from the end of the best epoch: 10.
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Fold 2 MSE: 0.3141, RMSE: 0.5604
#
# --- Fold 3 ---
# Epoch 1/10
# /opt/anaconda3/envs/ds_env/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 608/608 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0106 - val_loss: 0.0070
# Epoch 2/10
# 608/608 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0092 - val_loss: 0.0067
# Epoch 3/10
# 608/608 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0089 - val_loss: 0.0066
# Epoch 4/10
# 608/608 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0088 - val_loss: 0.0065
# Epoch 5/10
# 608/608 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0087 - val_loss: 0.0069
# Epoch 6/10
# 608/608 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0086 - val_loss: 0.0064
# Epoch 7/10
# 608/608 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0085 - val_loss: 0.0063
# Epoch 8/10
# 608/608 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0085 - val_loss: 0.0065
# Epoch 9/10
# 608/608 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0084 - val_loss: 0.0067
# Epoch 10/10
# 608/608 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0084 - val_loss: 0.0062
# Restoring model weights from the end of the best epoch: 10.
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 3 MSE: 0.2568, RMSE: 0.5067
#
# Cross-Validation Summary
# Average MSE: 0.3291
# Average RMSE: 0.5709
